# %% [markdown]
# # Embedding layer
# - in neural network similar to other layer we will have enbedding layer which will convert words to vector which is word embedding
#
# # Words Embedding [Feature Representation]
# - we have dataset as shown below
# ![image.png](attachment:image.png)
#
# - here we try to pass each words Xit to a embedding layer then convert it to vector and then send to simple RNN
#
# # Techniques we use for convert words to vector
# 1. One hot encoding
# - in this we first define vocab size like total number of unique words in dataset by let it be     |V|=10000
# - the we use one hot representation which say this vacab whereever that word is it make it 1 and rest 0, number of vector will be similar to  vocab size and for each make the word which it represent make it 1 at that position index and rest is 0 which is a sparse matrix and using sparse matrix cause overfitting as it only has 0's and 1's and also inefficient
# one such example given below
# ![image-2.png](attachment:image-2.png)
#
# - so we use words embedding like word2vec
#
# 2. Word Embedding [one of this is Word2Vec] and can put in embedding layer
# - vocab size |V|=10000
# - below i have shown some words and mark at the index they are present in whole 10000 word vocab size and these are the words we pick from first sentence(6 words)
# ![image-3.png](attachment:image-3.png)
# - in embedding layer we have feature representation which will tell us to canvert each word into a certain dimension of vector here lets take each word in 300 dimension vector, there will be other features as well like gender, loyal, age, food and so on ......300(how these 300 words will be coming please see in word2vec training video we will try is separately and put it in embedding layer) such feature will be there as we have decided to have 300 dimension feature vector
# - we make a matrix of (300,6) as for each feature to each word from first sentence
# - for word boy we try its relation with all the feature which are 300 and get a vector of (300,1)
# - example boy to gender let take value is -1 so for girl to gender it will 1 opposite
# - similary all values will be assign like this shown in below example all the values with this representation will be trained and provided a vector for boy we get a vectical vector
# ![image-4.png](attachment:image-4.png)
# - so when we give word boy to embedding layer it converts it to this vector of 300 dimension and then we pass it to RNN
# - it create a feature representation of each word in sentence
# - important things to remember in word2vec vocab size here it was |V|=1000, feature dimension here it was 300
