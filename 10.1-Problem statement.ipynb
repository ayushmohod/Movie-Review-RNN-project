# %% [markdown]
# ## End to End Deep learning projects using simple RNN
#
# 1. Here we take an IMDB dataset(movie reviews datasets)
# 2. it has text(reviews) and output(Positive/Negative) of 50,000 records
# 3. Solve it using simple RNN predictions and deployment (work on my aws instance)
#
#
# # workflow
#
# we take dataset--->do feature engineeering or transformation(make it ready to ingest in simple RNN)-->build simple RNN feed this data and train it-->get our model file(.h5 file)-->streamlit webapp-->further do the deployment
#
# # Training simple RNN
# - it would have two important components
# 1. embedding layers
# 2. simple RNN to training our neural network
#
#
# below is simple RNN
# ![image-2.png](attachment:image-2.png)
#
#
# in this we have data words like x11, x12 etc we need to convert these into vector and for that we
# use embeding we will use word2vec embedding technique to here convert words into vector
#
# - so firt in next lecture we would understand embedding layer and mathematical intution behind it and some practical example
